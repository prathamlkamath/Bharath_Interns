# %%
import pandas as pd

# %%
tita = pd.read_csv('train.csv')

# %%
tita.head(10)
# displays first 10 data from tita dataset
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
tita.shape
# gives the shape of the dataset tita
# Out:
# (891, 12)

# %%
import matplotlib.pyplot as plt

# %%
pip install seaborn
# If already installed you can skip this step. It is used to install seaborn library
# Out:
#   File "C:\Users\PRATHAM L KAMATH\AppData\Local\Temp\ipykernel_10924\307911327.py", line 1
#     pip install seaborn
#         ^
# SyntaxError: invalid syntax

# %%
import seaborn as sns

# %%
sns.countplot(x='Survived', data = tita)
# plotting a count plot on the data from tita and x axis is named as Survived
# Out:
# <AxesSubplot:xlabel='Survived', ylabel='count'>

# %%
sns.countplot(x='Survived', hue='Sex', data= tita)
# hue is used when creating pairplots in seaborn
# Out:
# <AxesSubplot:xlabel='Survived', ylabel='count'>

# %%
sns.countplot(x='Survived',hue='Pclass', data= tita)
# Out:
# <AxesSubplot:xlabel='Survived', ylabel='count'>

# %%
tita['Age'].plot.hist()
#plotting a histogram plot with Age as the parameter
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
tita['Fare'].plot.hist(bins = 20, figsize=(8,6))
# bins are like intervals or classes and figsize is for the dimension of the output plot and it is optional
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
sns.countplot(x='SibSp', data = tita, palette='summer')
#SibSp-how many siblings & spouses of the passenger aboard the Titanic
# Out:
# <AxesSubplot:xlabel='SibSp', ylabel='count'>

# %%
tita['Parch'].plot.hist()
#Parch-how many children and parents of the passenger aboard the Titanic.
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
sns.countplot(x='Parch',data=tita, palette='rocket')
# Out:
# <AxesSubplot:xlabel='Parch', ylabel='count'>

# %%
tita.isnull()
# Out:
#      PassengerId  Survived  Pclass   Name    Sex    Age  SibSp  Parch  Ticket  \
# 0          False     False   False  False  False  False  False  False   False
# 1          False     False   False  False  False  False  False  False   False
# 2          False     False   False  False  False  False  False  False   False
# 3          False     False   False  False  False  False  False  False   False
# 4          False     False   False  False  False  False  False  False   False
# ..           ...       ...     ...    ...    ...    ...    ...    ...     ...
# 886        False     False   False  False  False  False  False  False   False
# 887        False     False   False  False  False  False  False  False   False
# 888        False     False   False  False  False   True  False  False   False
# 889        False     False   False  False  False  False  False  False   False
# 890        False     False   False  False  False  False  False  False   False
#
#       Fare  Cabin  Embarked
# ...

# %%
tita.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
sns.heatmap(tita.isnull())
# Out:
# <AxesSubplot:>

# %%
sns.boxplot(x='Pclass',y='Age',data = tita)
# Out:
# <AxesSubplot:xlabel='Pclass', ylabel='Age'>

# %%
tita.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
tita.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
tita['Embarked'].fillna('S')
# Out:
# 0      S
# 1      C
# 2      S
# 3      S
# 4      S
#       ..
# 886    S
# 887    S
# 888    S
# 889    C
# 890    Q
# Name: Embarked, Length: 891, dtype: object

# %%
tita.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
titanic =tita.drop(columns=['Cabin'], axis="columns")

# %%
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Embarked
# 0      0         A/5 21171   7.2500        S
# 1      0          PC 17599  71.2833        C
# 2      0  STON/O2. 3101282   7.9250        S
# 3      0            113803  53.1000        S
# 4      0            373450   8.0500        S

# %%
titanic=titanic.fillna(method='ffill')

# %%
titanic.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       0
# dtype: int64

# %%
pd.get_dummies(titanic['Sex']).head()
# Out:
#    female  male
# 0       0     1
# 1       1     0
# 2       1     0
# 3       1     0
# 4       0     1

# %%
sex=pd.get_dummies(titanic['Sex'],drop_first=True).head()

# %%
sex.head()
# Out:
#    male
# 0     1
# 1     0
# 2     0
# 3     0
# 4     1

# %%
embark = pd.get_dummies(titanic['Embarked'])

# %%
embark
# Out:
#      C  Q  S
# 0    0  0  1
# 1    1  0  0
# 2    0  0  1
# 3    0  0  1
# 4    0  0  1
# ..  .. .. ..
# 886  0  0  1
# 887  0  0  1
# 888  0  0  1
# 889  1  0  0
# 890  0  1  0
#
# [891 rows x 3 columns]

# %%
embark = pd.get_dummies(titanic['Embarked'],drop_first=True)

# %%
embark
# Out:
#      Q  S
# 0    0  1
# 1    0  0
# 2    0  1
# 3    0  1
# 4    0  1
# ..  .. ..
# 886  0  1
# 887  0  1
# 888  0  1
# 889  0  0
# 890  1  0
#
# [891 rows x 2 columns]

# %%
pclass = pd.get_dummies(titanic['Pclass'])

# %%
pclass
# Out:
#      1  2  3
# 0    0  0  1
# 1    1  0  0
# 2    0  0  1
# 3    1  0  0
# 4    0  0  1
# ..  .. .. ..
# 886  0  1  0
# 887  1  0  0
# 888  0  0  1
# 889  1  0  0
# 890  0  0  1
#
# [891 rows x 3 columns]

# %%
pclass = pd.get_dummies(titanic['Pclass'],drop_first=True)

# %%
pclass.head()
# Out:
#    2  3
# 0  0  1
# 1  0  0
# 2  0  1
# 3  0  0
# 4  0  1

# %%
titanic=pd.concat([titanic,sex,embark,pclass],axis=1)

# %%
titanic.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male  35.0      0
# ...

# %%
titanic.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male  35.0      0
# ...

# %%
titanic.drop(['Name','PassengerId',"Pclass",'Ticket','Sex','Embarked'],axis =1, inplace = True)

# %%
titanic.head()
# Out:
#    Survived   Age  SibSp  Parch     Fare  male  Q  S  2  3
# 0         0  22.0      1      0   7.2500   1.0  0  1  0  1
# 1         1  38.0      1      0  71.2833   0.0  0  0  0  0
# 2         1  26.0      0      0   7.9250   0.0  0  1  0  1
# 3         1  35.0      1      0  53.1000   0.0  0  1  0  0
# 4         0  35.0      0      0   8.0500   1.0  0  1  0  1

# %%
x = titanic.drop('Survived',axis=1)
y = titanic['Survived']

# %%
from sklearn.model_selection import train_test_split
# lets train our model

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.7, random_state=4)

# %%
x_train.columns = x_train.columns.astype(str)
x_test.columns = x_test.columns.astype(str)

# %%
from sklearn.linear_model import LogisticRegression
lm = LogisticRegression()

# %%
x
# Out:
#       Age  SibSp  Parch     Fare  male  Q  S  2  3
# 0    22.0      1      0   7.2500   1.0  0  1  0  1
# 1    38.0      1      0  71.2833   0.0  0  0  0  0
# 2    26.0      0      0   7.9250   0.0  0  1  0  1
# 3    35.0      1      0  53.1000   0.0  0  1  0  0
# 4    35.0      0      0   8.0500   1.0  0  1  0  1
# ..    ...    ...    ...      ...   ... .. .. .. ..
# 886  27.0      0      0  13.0000   NaN  0  1  1  0
# 887  19.0      0      0  30.0000   NaN  0  1  0  0
# 888  19.0      1      2  23.4500   NaN  0  1  0  1
# 889  26.0      0      0  30.0000   NaN  0  0  0  0
# 890  32.0      0      0   7.7500   NaN  1  0  0  1
#
# [891 rows x 9 columns]

# %%
x.isnull().sum()
# Out:
# Age        0
# SibSp      0
# Parch      0
# Fare       0
# male     886
# Q          0
# S          0
# 2          0
# 3          0
# dtype: int64

# %%
x=x.fillna(method='ffill')

# %%
x.isnull().sum()
# Out:
# Age      0
# SibSp    0
# Parch    0
# Fare     0
# male     0
# Q        0
# S        0
# 2        0
# 3        0
# dtype: int64

# %%
x
# Out:
#       Age  SibSp  Parch     Fare  male  Q  S  2  3
# 0    22.0      1      0   7.2500   1.0  0  1  0  1
# 1    38.0      1      0  71.2833   0.0  0  0  0  0
# 2    26.0      0      0   7.9250   0.0  0  1  0  1
# 3    35.0      1      0  53.1000   0.0  0  1  0  0
# 4    35.0      0      0   8.0500   1.0  0  1  0  1
# ..    ...    ...    ...      ...   ... .. .. .. ..
# 886  27.0      0      0  13.0000   1.0  0  1  1  0
# 887  19.0      0      0  30.0000   1.0  0  1  0  0
# 888  19.0      1      2  23.4500   1.0  0  1  0  1
# 889  26.0      0      0  30.0000   1.0  0  0  0  0
# 890  32.0      0      0   7.7500   1.0  1  0  0  1
#
# [891 rows x 9 columns]

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.7, random_state=4)

# %%
x_train.columns = x_train.columns.astype(str)
x_test.columns = x_test.columns.astype(str)

# %%
lm.fit(x_train,y_train)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
predict = lm.predict(x_test)

# %%
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score

# %%
confusion_matrix(y_test,predict)
# Out:
# array([[353,  37],
#        [143,  91]], dtype=int64)

# %%
accuracy_score(y_test,predict)
# Out:
# 0.7115384615384616
